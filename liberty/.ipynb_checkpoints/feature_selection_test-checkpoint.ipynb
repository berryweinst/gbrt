# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from data_utils import parse_data
from gbrt_algorithm import gbrt
from feature_selection import ensemble_feature_importance
import operator
import pandas as pd

# %%
class hparams(object):
    def __init__(self, num_trees=50, max_depth=3, min_node_size=0, weight_decay=1.0, sub_samp=1.0, num_thresholds=3,
                 verbose=True):
        self.num_trees = num_trees
        self.max_depth = max_depth
        self.min_node_size = min_node_size
        self.weight_decay = weight_decay
        self.sub_samp = sub_samp
        self.num_thresholds = num_thresholds
        self.verbose = verbose

# %% [markdown]
# # Model Training

# %%
train_dataset, test_dataset = parse_data('data/train.csv')
params = hparams(num_trees=20, max_depth=4, min_node_size=0, weight_decay=0.1, sub_samp=0.7, verbose=False)
model = gbrt(train_data=train_dataset.data, test_data=test_dataset.data, label_name=train_dataset.label_name, params=params)
# Out:
# Add tree number 1
# Train mean loss is: 31112189239.236107
# Test mean loss is: 35291134370.18462
# Add tree number 2
# Train mean loss is: 25445714010.184822
# Test mean loss is: 29060439317.858673
# Add tree number 3
# Train mean loss is: 20855840186.343243
# Test mean loss is: 23710585317.80825
# Add tree number 4
# Train mean loss is: 17102770160.72697
# Test mean loss is: 19595634987.26525
# Add tree number 5
# Train mean loss is: 14033856008.333319
# Test mean loss is: 16184458454.091766
# Add tree number 6
# Train mean loss is: 11559866062.463404
# Test mean loss is: 13236123713.093733
# Add tree number 7
# Train mean loss is: 9532329910.1845
# Test mean loss is: 11049097923.432484
# Add tree number 8
# Train mean loss is: 7897423639.7595415
# Test mean loss is: 9291366768.122683
# Add tree number 9
# Train mean loss is: 6536069120.187096
# Test mean loss is: 7756875881.023926
# Add tree number 10
# Train mean loss is: 5438199254.926105
# Test mean loss is: 6558048247.117917
# Add tree number 11
# Train mean loss is: 4533269513.57912
# Test mean loss is: 5537908206.570036
# Add tree number 12
# Train mean loss is: 3795892441.493478
# Test mean loss is: 4743535225.857832
# Add tree number 13
# Train mean loss is: 3188942511.952181
# Test mean loss is: 4082145732.15776
# Add tree number 14
# Train mean loss is: 2689142837.595157
# Test mean loss is: 3496345718.256597
# Add tree number 15
# Train mean loss is: 2279248594.415861
# Test mean loss is: 3036686587.548019
# Add tree number 16
# Train mean loss is: 1934612300.1155367
# Test mean loss is: 2676603068.344434
# Add tree number 17
# Train mean loss is: 1655655411.765814
# Test mean loss is: 2371967187.524297
# Add tree number 18
# Train mean loss is: 1429315570.4611533
# Test mean loss is: 2132030097.384229
# Add tree number 19
# Train mean loss is: 1251371371.8000536
# Test mean loss is: 1937676215.606821
# Add tree number 20
# Train mean loss is: 1095392323.7712653
# Test mean loss is: 1779447283.7731595

# %% [markdown]
# # Feature selection

# %%
features_dict = ensemble_feature_importance(test_dataset.data, train_dataset.label_name, model)
n = 10
features_dict = sorted(features_dict.items(), key=operator.itemgetter(1), reverse=True)[0:n]

# %%
for idx, tree in enumerate(model.trees):
    print('Tree #%d partition description' % (idx))
    print('==============================')
    tree.root.print_sub_tree()
    if idx == 4:
        break
# Out:
# Tree #0 partition description
# ==============================
# if x['OverallQual'] <= 6 then:
# 	if x['Neighborhood'] <= 10.0 then:
# 		if x['TotalBsmtSF'] <= 894 then:
# 			if x['GrLivArea'] <= 1348 then:
# 				return -103105.704
# 			if x['GrLivArea'] > 1348 then:
# 				return -133972.56097560975
# 		if x['TotalBsmtSF'] > 894 then:
# 			if x['KitchenQual'] <= 2.0 then:
# 				return -136966.01470588235
# 			if x['KitchenQual'] > 2.0 then:
# 				return -164616.30434782608
# 	if x['Neighborhood'] > 10.0 then:
# 		if x['GrLivArea'] <= 1097 then:
# 			if x['GarageCars'] <= 1 then:
# 				return -115943.75
# 			if x['GarageCars'] > 1 then:
# 				return -142343.10344827586
# 		if x['GrLivArea'] > 1097 then:
# 			if x['GrLivArea'] <= 1732 then:
# 				return -169922.78
# 			if x['GrLivArea'] > 1732 then:
# 				return -197704.54545454544
# if x['OverallQual'] > 6 then:
# 	if x['OverallQual'] <= 8 then:
# 		if x['GarageCars'] <= 2 then:
# 			if x['GrLivArea'] <= 1959 then:
# 				return -199605.17610062895
# 			if x['GrLivArea'] > 1959 then:
# 				return -252094.13461538462
# 		if x['GarageCars'] > 2 then:
# 			if x['Neighborhood'] <= 20.0 then:
# 				return -251493.36842105264
# 			if x['Neighborhood'] > 20.0 then:
# 				return -317111.5
# 	if x['OverallQual'] > 8 then:
# 		if x['BsmtHalfBath'] <= 0 then:
# 			if x['YearRemodAdd'] <= 2008 then:
# 				return -358609.25
# 			if x['YearRemodAdd'] > 2008 then:
# 				return -474437.2
# 		if x['BsmtHalfBath'] > 0 then:
# 			return -755000.0
# Tree #1 partition description
# ==============================
# if x['OverallQual'] <= 6 then:
# 	if x['Neighborhood'] <= 10.0 then:
# 		if x['Fireplaces'] <= 0 then:
# 			if x['OverallQual'] <= 4 then:
# 				return -86644.00891670362
# 			if x['OverallQual'] > 4 then:
# 				return -110648.83759972017
# 		if x['Fireplaces'] > 0 then:
# 			if x['GarageCars'] <= 1 then:
# 				return -121327.64240898131
# 			if x['GarageCars'] > 1 then:
# 				return -143549.69233432072
# 	if x['Neighborhood'] > 10.0 then:
# 		if x['GrLivArea'] <= 1097 then:
# 			if x['BsmtFinSF1'] <= 495 then:
# 				return -105123.87106991313
# 			if x['BsmtFinSF1'] > 495 then:
# 				return -124539.26714078693
# 		if x['GrLivArea'] > 1097 then:
# 			if x['GrLivArea'] <= 1571 then:
# 				return -150259.3439792415
# 			if x['GrLivArea'] > 1571 then:
# 				return -172739.77657439836
# if x['OverallQual'] > 6 then:
# 	if x['GarageCars'] <= 2 then:
# 		if x['TotalBsmtSF'] <= 1368 then:
# 			if x['MSSubClass'] <= 13.0 then:
# 				return -162857.54550243428
# 			if x['MSSubClass'] > 13.0 then:
# 				return -201585.9881280485
# 		if x['TotalBsmtSF'] > 1368 then:
# 			if x['FireplaceQu'] <= 4.0 then:
# 				return -203390.018752207
# 			if x['FireplaceQu'] > 4.0 then:
# 				return -263377.54061314557
# 	if x['GarageCars'] > 2 then:
# 		if x['OverallQual'] <= 8 then:
# 			if x['GrLivArea'] <= 2376 then:
# 				return -237440.2546202033
# 			if x['GrLivArea'] > 2376 then:
# 				return -314377.7566639
# 		if x['OverallQual'] > 8 then:
# 			if x['Condition1'] <= 5.0 then:
# 				return -366848.9921424955
# 			if x['Condition1'] > 5.0 then:
# 				return -248976.78827657853
# Tree #2 partition description
# ==============================
# if x['OverallQual'] <= 7 then:
# 	if x['Neighborhood'] <= 10.0 then:
# 		if x['FireplaceQu'] <= 2.0 then:
# 			if x['TotalBsmtSF'] <= 864 then:
# 				return -84273.35982442604
# 			if x['TotalBsmtSF'] > 864 then:
# 				return -108602.33681924678
# 		if x['FireplaceQu'] > 2.0 then:
# 			if x['GarageCars'] <= 1 then:
# 				return -107930.65295205433
# 			if x['GarageCars'] > 1 then:
# 				return -137144.28115005692
# 	if x['Neighborhood'] > 10.0 then:
# 		if x['OverallQual'] <= 6 then:
# 			if x['GrLivArea'] <= 1180 then:
# 				return -108884.34315192584
# 			if x['GrLivArea'] > 1180 then:
# 				return -144465.74998213528
# 		if x['OverallQual'] > 6 then:
# 			if x['GrLivArea'] <= 1640 then:
# 				return -153776.00868179358
# 			if x['GrLivArea'] > 1640 then:
# 				return -192958.23840425076
# if x['OverallQual'] > 7 then:
# 	if x['BsmtFinSF1'] <= 1121 then:
# 		if x['GrLivArea'] <= 2217 then:
# 			if x['SaleType'] <= 6.0 then:
# 				return -189327.16706535913
# 			if x['SaleType'] > 6.0 then:
# 				return -243875.72745444387
# 		if x['GrLivArea'] > 2217 then:
# 			if x['GrLivArea'] <= 2775 then:
# 				return -254042.2801331062
# 			if x['GrLivArea'] > 2775 then:
# 				return -342825.51223921805
# 	if x['BsmtFinSF1'] > 1121 then:
# 		if x['FullBath'] <= 2 then:
# 			if x['GrLivArea'] <= 1826 then:
# 				return -257462.17241309324
# 			if x['GrLivArea'] > 1826 then:
# 				return -347059.21463846194
# 		if x['FullBath'] > 2 then:
# 			if x['LotFrontage'] <= 47.0 then:
# 				return -474869.9834692728
# 			if x['LotFrontage'] > 47.0 then:
# 				return -642797.1392821812
# Tree #3 partition description
# ==============================
# if x['OverallQual'] <= 6 then:
# 	if x['OverallQual'] <= 5 then:
# 		if x['TotalBsmtSF'] <= 1064 then:
# 			if x['Neighborhood'] <= 6.0 then:
# 				return -73625.02560557183
# 			if x['Neighborhood'] > 6.0 then:
# 				return -93668.2947252172
# 		if x['TotalBsmtSF'] > 1064 then:
# 			if x['FireplaceQu'] <= 2.0 then:
# 				return -102915.87320929127
# 			if x['FireplaceQu'] > 2.0 then:
# 				return -125849.04037830465
# 	if x['OverallQual'] > 5 then:
# 		if x['GarageCars'] <= 1 then:
# 			if x['LotArea'] <= 8741 then:
# 				return -86249.04744441819
# 			if x['LotArea'] > 8741 then:
# 				return -109206.70581528237
# 		if x['GarageCars'] > 1 then:
# 			if x['GrLivArea'] <= 1470 then:
# 				return -116499.43130087359
# 			if x['GrLivArea'] > 1470 then:
# 				return -142230.51114043122
# if x['OverallQual'] > 6 then:
# 	if x['OverallQual'] <= 7 then:
# 		if x['GrLivArea'] <= 1929 then:
# 			if x['1stFlrSF'] <= 1431 then:
# 				return -130899.38986615674
# 			if x['1stFlrSF'] > 1431 then:
# 				return -168575.79855678318
# 		if x['GrLivArea'] > 1929 then:
# 			if x['LandSlope'] <= 1.0 then:
# 				return -186449.7360010908
# 			if x['LandSlope'] > 1.0 then:
# 				return -279763.6595946048
# 	if x['OverallQual'] > 7 then:
# 		if x['Neighborhood'] <= 22.0 then:
# 			if x['1stFlrSF'] <= 1506 then:
# 				return -171108.09857189108
# 			if x['1stFlrSF'] > 1506 then:
# 				return -206845.92476148406
# 		if x['Neighborhood'] > 22.0 then:
# 			if x['GrLivArea'] <= 1944 then:
# 				return -210660.69709184096
# 			if x['GrLivArea'] > 1944 then:
# 				return -286670.11790382763
# Tree #4 partition description
# ==============================
# if x['OverallQual'] <= 6 then:
# 	if x['GarageCars'] <= 1 then:
# 		if x['1stFlrSF'] <= 810 then:
# 			if x['OverallQual'] <= 4 then:
# 				return -44411.95982157371
# 			if x['OverallQual'] > 4 then:
# 				return -71002.77683483505
# 		if x['1stFlrSF'] > 810 then:
# 			if x['BsmtFinSF1'] <= 354 then:
# 				return -75174.19592054824
# 			if x['BsmtFinSF1'] > 354 then:
# 				return -91919.04176934026
# 	if x['GarageCars'] > 1 then:
# 		if x['OverallQual'] <= 5 then:
# 			if x['BsmtFinSF1'] <= 417 then:
# 				return -80866.95417418801
# 			if x['BsmtFinSF1'] > 417 then:
# 				return -100253.73803273516
# 		if x['OverallQual'] > 5 then:
# 			if x['Neighborhood'] <= 17.0 then:
# 				return -109614.14145059032
# 			if x['Neighborhood'] > 17.0 then:
# 				return -136859.0585035606
# if x['OverallQual'] > 6 then:
# 	if x['1stFlrSF'] <= 1601 then:
# 		if x['GrLivArea'] <= 1983 then:
# 			if x['Neighborhood'] <= 15.0 then:
# 				return -108798.67751642308
# 			if x['Neighborhood'] > 15.0 then:
# 				return -136170.36949599668
# 		if x['GrLivArea'] > 1983 then:
# 			if x['BsmtExposure'] <= 2.0 then:
# 				return -161953.9810950534
# 			if x['BsmtExposure'] > 2.0 then:
# 				return -212978.8910098846
# 	if x['1stFlrSF'] > 1601 then:
# 		if x['Neighborhood'] <= 20.0 then:
# 			if x['BsmtUnfSF'] <= 868 then:
# 				return -204109.93441742947
# 			if x['BsmtUnfSF'] > 868 then:
# 				return -139917.34600807732
# 		if x['Neighborhood'] > 20.0 then:
# 			if x['FullBath'] <= 2 then:
# 				return -227457.26301951797
# 			if x['FullBath'] > 2 then:
# 				return -387018.299495636

# %%
features_dict = pd.DataFrame(features_dict, columns=['feature', 'score'])
features_dict
# Out:
#         feature     score
# 0   OverallQual  1.000000
# 1  Neighborhood  0.232626
# 2     GrLivArea  0.222492
# 3   TotalBsmtSF  0.092156
# 4      1stFlrSF  0.086419
# 5     ExterQual  0.078609
# 6   KitchenQual  0.071677
# 7    GarageCars  0.056765
# 8    BsmtFinSF1  0.052365
# 9      FullBath  0.033520

# %%
plot = features_dict.plot(kind='bar',legend=None,title="Feature importance", x='feature', figsize=(15,6))
plot.set_xlabel("feature")
plot.set_ylabel("score")
